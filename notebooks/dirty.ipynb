# %%
import pandas as pd
from src.preprocessing import VarianceFilter, DataframeTransformerWrapper

# %%
data = pd.read_csv('../src/extracted_features/features.csv', index_col=0)

# %%
data
# Out:
#                        original_firstorder_10Percentile  \
# id
# Normal-5694.png                                    36.0
# Normal-1419.png                                    48.0
# Normal-6196.png                                    59.0
# Normal-1312.png                                    62.0
# Lung_Opacity-3452.png                             126.0
# ...                                                 ...
# Lung_Opacity-3747.png                              64.0
# Lung_Opacity-313.png                               80.0
# COVID-1723.png                                     49.0
# Lung_Opacity-1487.png                              61.0
# Normal-4469.png                                    40.0
#
#                        original_firstorder_90Percentile  \
# id
# Normal-5694.png                                   117.0
# Normal-1419.png                                   136.0
# Normal-6196.png                                   145.0
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
vf = VarianceFilter(1e-10)
ss = DataframeTransformerWrapper(StandardScaler())

# %%
vf.fit_transform(ss.fit_transform(data))
# Out:
# Calculating variance
# Selecting features
#                        original_firstorder_10Percentile  \
# id
# Normal-5694.png                               -1.206019
# Normal-1419.png                               -0.778465
# Normal-6196.png                               -0.386541
# Normal-1312.png                               -0.279652
# Lung_Opacity-3452.png                          2.000635
# ...                                                 ...
# Lung_Opacity-3747.png                         -0.208393
# Lung_Opacity-313.png                           0.361679
# COVID-1723.png                                -0.742835
# Lung_Opacity-1487.png                         -0.315282
# Normal-4469.png                               -1.063501
#
#                        original_firstorder_90Percentile  \
# id
# Normal-5694.png                               -1.182403
# Normal-1419.png                               -0.444716
# Normal-6196.png                               -0.095285
# ...
